# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.ones(2)
# Out:
# tensor([1., 1.])

# %%
t = torch.rand((4,5))

# %%
pnpm = t.numpy()

# %%
pnpm[0]
# Out:
# array([0.5849467 , 0.38930857, 0.29346782, 0.6529508 , 0.58786476],
#       dtype=float32)

# %%
plt.plot(pnpm,'o--')
