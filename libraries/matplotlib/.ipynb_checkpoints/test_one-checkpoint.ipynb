# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_one = np.random.rand(6)
data_one
# Out:
# array([0.60869904, 0.70390215, 0.40013411, 0.7778066 , 0.15979542,
#        0.82153458])

# %%
data_two = np.random.rand(6)
data_two
# Out:
# array([1., 1., 1., 1., 1., 1.])

# %%
plt.xlabel('Hello')
plt.legend('Yo yo')
plt.plot(data_one,data_two,'o--',label="super testo")
