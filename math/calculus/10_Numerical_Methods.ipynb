# %% [markdown]
# # Numerical MethodsExploring numerical methods for solving calculus problems, including numerical differentiation, numerical integration, and solving differential equations using Euler's method and Runge-Kutta methods.
