# %% [markdown]
# # Descriptive StatisticsExploration of data using measures such as mean, median, mode, variance, and standard deviation. Introduction to graphical representations like histograms and box plots.
