# %% [markdown]
# # Statistical Computing with RIntroduction to statistical computing using R, including data manipulation, visualization, and basic statistical analysis with libraries like tidyverse and ggplot2.
